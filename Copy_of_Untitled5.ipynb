# %% [markdown]
# <a href="https://colab.research.google.com/github/deva0018/VITBML-EDA1/blob/master/Copy_of_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# team members are 19PA1A05D4,19PA1A05F4,19PA1A05E5,19PA1A05H0

# %%
import pandas as pd

from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-bf7f5bde-565e-4adb-bd29-0ebb9b3140de" name="files[]" multiple disabled />
#      <output id="result-bf7f5bde-565e-4adb-bd29-0ebb9b3140de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving supermarket_sales - Sheet1.csv to supermarket_sales - Sheet1 (1).csv

# %%
import io
import pandas as pd

df=pd.read_csv(io.BytesIO(uploaded['supermarket_sales - Sheet1.csv']))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #features description

# %% [markdown]
# ####Invoice ID-Computer generated sales slip invoice identification number
# ####supercenter- (3 branches are available identified by A, B and C)
# ####City-Location of supercenters
# ####Customer type-Type of customers, recorded by Members for customers using member card and Normal for without member card
# ####Gender-Gender type of customer
# ####Product line-General item categorization groups
# ####Unit price-Price of each product in $
# ####QuantityNumber of products purchased by customer
# ####Tax 5%-5% tax fee for customer buying
# ####Total-Total price including tax
# ####Date-Date of purchase
# ####Time-Purchase time
# ####Payment-Payment used by customer for purchase
# ####cogs-Cost of goods sold
# ####gross margin percentage-Gross margin percentage
# ####gross income-Gross income
# ####Rating-Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %%
df.head()
# Out:
#     Invoice ID Branch       City  ... gross margin percentage gross income Rating
# 0  750-67-8428      A     Yangon  ...                4.761905      26.1415    9.1
# 1  226-31-3081      C  Naypyitaw  ...                4.761905       3.8200    9.6
# 2  631-41-3108      A     Yangon  ...                4.761905      16.2155    7.4
# 3  123-19-1176      A     Yangon  ...                4.761905      23.2880    8.4
# 4  373-73-7910      A     Yangon  ...                4.761905      30.2085    5.3
#
# [5 rows x 17 columns]

# %%
#to find how the total income changes from mean  
sns.distplot(df["Total"])

# %%
#to find the mean total bill spend by male and female

# %%
sns.barplot(x='Gender',y='Total',data=df)

# %%
#to count the number of male and female using plots
sns.countplot(x='Gender',data=df)

# %%
#to find how total money paid and tax are related
sns.jointplot(x='Total',y='Tax 5%',data=df,kind="scatter")

# %%
#to find how the payment and grossincome varies with each other
sns.boxplot(x='Payment',y='gross income',data=df,hue='Gender')

# %%
#to find which type of payment people are preferring mostly
sns.violinplot(x='Payment',y='Total',data=df,palette='rainbow',hue='Gender')

# %%
df.corr()
# Out:
#                            Unit price      Quantity  ...  gross income        Rating
# Unit price               1.000000e+00  1.077756e-02  ...  6.339621e-01 -8.777507e-03
# Quantity                 1.077756e-02  1.000000e+00  ...  7.055102e-01 -1.581490e-02
# Tax 5%                   6.339621e-01  7.055102e-01  ...  1.000000e+00 -3.644170e-02
# Total                    6.339621e-01  7.055102e-01  ...  1.000000e+00 -3.644170e-02
# cogs                     6.339621e-01  7.055102e-01  ...  1.000000e+00 -3.644170e-02
# gross margin percentage -6.998957e-16 -3.849075e-16  ...  2.461896e-16  2.042714e-15
# gross income             6.339621e-01  7.055102e-01  ...  1.000000e+00 -3.644170e-02
# Rating                  -8.777507e-03 -1.581490e-02  ... -3.644170e-02  1.000000e+00
#
# [8 rows x 8 columns]

# %%
#a heat plot between corelated data which makes visualization better
sns.heatmap(df.corr(),cmap='coolwarm')

# %%
a=df.pivot_table(values='Total',index='Gender',columns='Payment')

# %%
#another heatmap for how many number of male and female are using credit card ,cash,ewallet for payment
sns.heatmap(a,cmap='magma')

# %%
#to find how is the sales of different types of products
plt.figure(figsize=(3,30))
sns.factorplot(x='Product line',y='Total',data=df,kind='box')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#to find the median total spend by the male and female using swarmplot and violinplot

# %%
sns.violinplot(x='City',y='Total',data=df,hue='Gender',palette='rainbow')

# %%
sns.swarmplot(x='City',y='Total',data=df,hue='Gender')

# %%
#to find the pairwise relatioship between entire data  frame we use generally a plot called pairplot

# %%
sns.pairplot(df,hue='Gender')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#to find which type of branch has maximum mean income

# %%
sns.barplot(x='Branch',y='gross income',hue='Gender',data=df)

# %%
#to in which type products the peoplr are actually interested
sns.countplot(df['Product line'],saturation=0.75,dodge=True)

# %%
#from the above we find that people are more interesred in buying accessories

# %%
#to find the median rating of the costomers for A,B,C shops

# %%
sns.boxplot(x='Branch',y='Rating',data=df,hue='Gender')

# %%
#to find how the total money and gross in come are related

# %%
sns.jointplot(x='Total',y='gross income',data=df,kind='scatter')

# %%
#to find which city max mean gross income

# %%
sns.barplot(x='City',y='gross income',data=df)

# %%
#from this nayptitawcity has mean gross income

# %%
#an area plot for the gross income
plt.style.use('dark_background')
df['gross income'].plot.area(alpha=0.4)

# %%
#to find the highest tax paid by  person among some varibles
a=df['Tax 5%']
a[0:10].plot()

# %% [markdown]
# By this we plot all plots between every varibles
# Also we find the median through graphs for various data
